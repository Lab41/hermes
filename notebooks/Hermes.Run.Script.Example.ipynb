# %% [markdown]
# ##This notebooks lays out the steps we have been using to run Hermes
#
# ###It saves intermediary products then reads those products back into the context for the next step
# ###This helps prevent any losses during the run

# %% [markdown]
# ###First set up your spark context (if necessary) and load the hermes.zip into context
# ###hermes.zip can be found on GitHub at https://github.com/Lab41/hermes.git

# %%
#This block of code will set up a spark content and sql context if you are running locally
#If you are on cluster or have deployed spark a different way you don't need this
from pyspark import SparkContext, SparkConf 
from pyspark.sql import SQLContext 

try:
    sc = SparkContext()
except:
    sc = SparkContext._active_spark_context

sqlCtx = SQLContext(sc)

# %%
sc.addPyFile('hermes/hermes.zip')
from src import hermes_run_script
import pandas as pd

# %% [markdown]
# ###Read in the data - for instance the MovieLens data can be found at: http://grouplens.org/datasets/movielens/
#
# ###The data then needs to be transformed into json files.  Each dataset has its own ETL folder in hermes/src/utils
# ###Once transformed then you should load the json files

# %%
movies = sqlCtx.read.json(
    'movielens_20m_movies.json.gz', 
)

ratings = sqlCtx.read.json(
    'movielens_20m_ratings.json.gz',
)

#We found the best tag set is in MovieLens 20M and it usable for all movielens
tags = sqlCtx.read.json('movielens_20m_tags.json.gz')

# %% [markdown]
# ###Set up all of the parameters necessary for the runner

# %%
#name of the dataset: will be used for to get the correct vectorizer and when saving files
data_name = 'movielens_20m'
#the types of user vectors to assess
#each dataset has different user vectors that can be chosen
user_vector_types = ['ratings', 'pos_ratings', 'ratings_to_interact']
#the types of content vectors to assess
#each dataset has different content vectors that can be chosen
content_vector_types = ['genre','tags'] 

#the directory where intermediate files will be saved including user vectors, content vectors, and predictions
#this can be HDFS
directory = 'HDFS/movielens/data'
#the directory for the csv results files.
#this should not be HDFS
results_directory = 'movielens/results'

#the collaborative filtering algorithms to run
cf_predictions = ['cf_mllib', 'cf_item', 'cf_user']
#the content based algorithms to run
cb_predictions = ['cb_vect', 'cb_kmeans_100', 'cb_kmeans_1000']

#the number of predictions to give to a user
result_runs = [100, 1000] 

#any additional items that are necessary to run the content vectors
#for MovieLens this includes the user tags if you want to run the tag content vector
support_files = {'num_tags':300, 'tag_rdd':tags}

# %% [markdown]
# ###Pass in all the variables into the Hermes Runner

# %%
runner = hermes_run_script.hermes_run(ratings, movies, user_vector_types, content_vector_types,\
    sqlCtx, sc, data_name, directory, results_directory, cf_predictions, cb_predictions, \
    result_runs, num_partitions=30, **support_files)

# %%
#run the vectorizers
runner.run_vectorizer()

# %%
#run the collaborative filtering algorithms
runner.run_cf_predictions()

# %%
#run the content based algorithms
runner.run_cb_predictions()

# %%
#get the results for the collaborative filtering predictions
runner.run_cf_results()

# %%
#get the results for the content based predictions
runner.run_cb_results()

# %%
#consolidate all of the results into a single csv file
runner.consolidate_results()

# %% [markdown]
# ###View the results

# %%
full_results_path = results_directory + data_name + '_full_results.csv'
results =  pd.read_csv(full_results_path, delimiter=',', index_col=0)

# %%
#View part or all of the results
results[['user_vector','content_vector','N','alg_type','serendipity', 'cat_coverage', 'rmse']]
# Out:
#             user_vector content_vector     N        alg_type  serendipity  \
# 0           pos_ratings          genre  1000         cb_vect     0.127970
# 1               ratings          genre   100   cb_kmeans_100     0.229742
# 2           pos_ratings          genre  1000         cf_user     0.047091
# 3   ratings_to_interact          genre  1000         cb_vect     0.127515
# 4           pos_ratings          genre   100         cf_user     0.018797
# 5               ratings          genre  1000         cb_vect     0.101428
# 6               ratings          genre   100        cf_mllib     0.075411
# 7   ratings_to_interact          genre   100   cb_kmeans_100     0.274341
# 8           pos_ratings           tags  1000         cb_vect     0.087713
# 9   ratings_to_interact          genre  1000         cf_user     0.057605
# 10          pos_ratings          genre  1000         cf_item     0.350344
# 11  ratings_to_interact          genre  1000        cf_mllib     0.104021
# 12  ratings_to_interact          genre   100         cb_vect     0.218246
# 13              ratings          genre  1000         cb_vect     0.103222
# 14  ratings_to_interact          genre   100         cf_item     0.286285
# 15  ratings_to_interact           tags   100         cb_vect     0.107325
# 16              ratings          genre  1000         cf_user     0.032895
# 17  ratings_to_interact          genre  1000         cf_item     0.093958
# 18  ratings_to_interact           tags  1000         cb_vect     0.094904
# 19              ratings           tags   100   cb_kmeans_100     0.168451
# 20          pos_ratings           tags   100         cb_vect     0.092884
# 21  ratings_to_interact           tags  1000  cb_kmeans_1000     0.114713
# 22          pos_ratings          genre   100        cf_mllib     0.093116
# 23              ratings           tags  1000         cb_vect     0.071259
# 24          pos_ratings          genre   100         cb_vect     0.242384
# 25  ratings_to_interact          genre   100        cf_mllib     0.238649
# 26          pos_ratings          genre   100   cb_kmeans_100     0.247484
# 27              ratings           tags  1000  cb_kmeans_1000     0.086146
# 28              ratings          genre   100  cb_kmeans_1000     0.206245
# 29              ratings          genre   100         cb_vect     0.202159
# 30              ratings          genre  1000  cb_kmeans_1000     0.105056
# 31              ratings          genre  1000         cf_item     0.150584
# 32              ratings          genre   100   cb_kmeans_100     0.228856
# 33          pos_ratings           tags  1000  cb_kmeans_1000     0.106437
# 34              ratings          genre   100         cb_vect     0.202552
# 35  ratings_to_interact           tags   100   cb_kmeans_100     0.178447
# 36  ratings_to_interact          genre   100         cf_user     0.111164
# 37              ratings          genre   100         cf_item     0.406931
# 38              ratings          genre   100         cf_user     0.011230
# 39              ratings          genre  1000        cf_mllib     0.058938
# 40  ratings_to_interact          genre  1000  cb_kmeans_1000     0.140200
# 41          pos_ratings          genre  1000        cf_mllib     0.079068
# 42              ratings           tags   100         cb_vect     0.086813
# 43          pos_ratings          genre   100         cf_item     0.357078
# 44          pos_ratings          genre  1000  cb_kmeans_1000     0.139120
# 45          pos_ratings           tags   100   cb_kmeans_100     0.201609
#
#     cat_coverage      rmse
# 0      28.304557  0.579861
# 1       2.698327  1.300742
# 2      28.304557  0.474636
# 3      26.983270  0.791903
# 4       2.830456  0.454204
# 5      26.983270  1.198814
# 6       2.698327  0.757524
# 7       2.698327  0.820626
# 8      28.304557  0.488214
# 9      26.983270  0.474519
# 10     28.304557  0.471052
# 11     26.983270  0.464547
# 12      2.698327  0.684127
# 13     26.983270  1.199120
# 14      2.698327  0.386307
# 15      2.698327  0.846901
# 16     26.983270  0.885211
# 17     26.983270  0.498258
# 18     26.983270  1.037724
# 19      2.671344  1.489720
# 20      2.830456  0.495794
# 21     26.713438  1.147776
# 22      2.830456  0.513351
# 23     26.983270  1.356846
# 24      2.830456  0.618196
# 25      2.698327  0.424146
# 26      2.802151  0.576947
# 27     26.983270  1.392828
# 28      2.698327  1.253268
# 29      2.698327  1.264294
# 30     26.713438  1.261918
# 31     26.983270  1.003187
# 32      2.698327  1.299784
# 33     28.304557  0.481822
# 34      2.698327  1.272136
# 35      2.671344  1.100347
# 36      2.698327  0.294139
# 37      2.698327  1.493486
# 38      2.698327  0.841587
# 39     26.983270  0.814773
# 40     26.983270  0.931490
# 41     28.304557  0.481792
# 42      2.698327  1.209604
# 43      2.830456  0.539761
# 44     28.304557  0.558985
# 45      2.802151  0.483458
